# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/superstore-sales-dataset-analysis/__results__.html
# /kaggle/input/superstore-sales-dataset-analysis/__resultx__.html
# /kaggle/input/superstore-sales-dataset-analysis/__notebook__.ipynb
# /kaggle/input/superstore-sales-dataset-analysis/__output__.json
# /kaggle/input/superstore-sales-dataset-analysis/custom.css
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___20_1.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___28_1.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___26_1.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___33_1.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___30_1.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___21_2.png
# /kaggle/input/superstore-sales-dataset-analysis/__results___files/__results___24_1.png
# ...

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/kaggle/input/sales-forecasting/train.csv')
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
data.shape
# Out:
# (9800, 18)

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df=data.drop(['Row ID'],axis=1)
df.head()
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %% [markdown]
# #### Finding null value

# %%
df[df['Postal Code'].isnull()]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 2234  CA-2018-104066  05/12/2018  10/12/2018  Standard Class    QJ-19255
# 5274  CA-2016-162887  07/11/2016  09/11/2016    Second Class    SV-20785
# 8798  US-2017-150140  06/04/2017  10/04/2017  Standard Class    VM-21685
# 9146  US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class    CB-12535
# 9386  US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class    RM-19375
# 9741  CA-2016-117086  08/11/2016  12/11/2016  Standard Class    QJ-19255
#
#          Customer Name      Segment        Country        City    State  \
# ...

# %% [markdown]
# ##### Result : We need find it teh Postal Code of East Burlington,Vermont, United States.
#
# ##### The postal code (ZIP code) is 5401.

# %% [markdown]
# ### Fxing null value

# %%
df['Postal Code']=df['Postal Code'].fillna(5401)

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df[df['City']=='Burlington']
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 683   US-2018-168116  04/11/2018  04/11/2018        Same Day    GT-14635
# 684   US-2018-168116  04/11/2018  04/11/2018        Same Day    GT-14635
# 1008  US-2018-106705  26/12/2018  01/01/2019  Standard Class    PO-18850
# 1038  CA-2018-121818  20/11/2018  21/11/2018     First Class    JH-15430
# 1039  CA-2018-121818  20/11/2018  21/11/2018     First Class    JH-15430
# 1393  CA-2018-124828  03/07/2018  04/07/2018     First Class    YS-21880
# 2234  CA-2018-104066  05/12/2018  10/12/2018  Standard Class    QJ-19255
# 2928  US-2018-120390  19/10/2018  26/10/2018  Standard Class    TH-21550
# 5065  CA-2018-142090  30/11/2018  07/12/2018  Standard Class    SC-20380
# 5066  CA-2018-142090  30/11/2018  07/12/2018  Standard Class    SC-20380
# 5274  CA-2016-162887  07/11/2016  09/11/2016    Second Class    SV-20785
# 8317  CA-2018-130904  11/04/2018  16/04/2018  Standard Class    HM-14980
# ...

# %% [markdown]
# ### Creating month columns

# %%
df['Month']=df['Order Date'].str[3:5]
df['Month']=df['Month'].astype('int32')
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9795  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9796  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# ### Name the months

# %%
months = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# %%
months[8]
# Out:
# 'August'

# %%
df['Month']= [months[i] for i in df['Month']]

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9795  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9796  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# ### Changing Order date & Ship Date data type

# %%
df.dtypes
# Out:
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Month             object
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df.head()
# Out:
#          Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08  11/11/2017    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12  16/06/2017    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code             float64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Month                    object
# dtype: object

# %% [markdown]
# ### Creating year columns

# %%
df['Year']=df['Order Date'].dt.year
df.head(7)
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 5  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 6  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...

# %%
df['Year'].value_counts()
# Out:
# Year
# 2018    3258
# 2017    2534
# 2016    2055
# 2015    1953
# Name: count, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# Month
# November     1449
# December     1382
# September    1354
# October       809
# May           725
# July          697
# August        693
# June          691
# March         680
# April         657
# January       366
# February      297
# Name: count, dtype: int64

# %% [markdown]
# #### Sales volume by month

# %%
months_df = df.groupby('Month')['Sales'].sum().reset_index()

months_df.sort_values(by='Sales', ascending=False)
# Out:
#         Month        Sales
# 9    November  350161.7110
# 2    December  321480.1695
# 11  September  300103.4117
# 10    October  199496.2947
# 7       March  197573.5872
# 1      August  157315.9270
# 8         May  154086.7237
# 6        June  145837.5233
# 5        July  145535.6890
# 0       April  136283.0006
# 4     January   94291.6296
# 3    February   59371.1154

# %%
plt.bar(months_df["Month"], months_df["Sales"])
plt.xlabel("Months")
plt.ylabel("Sales Volume")
plt.xticks(fontsize=8,rotation=90)
plt.yticks(fontsize=8)
plt.title('Sales Volume by Month', fontsize=13)
plt.show()

# %% [markdown]
# ### Sales volume by year

# %%
year_df = df.groupby('Year')['Sales'].sum().reset_index()
year_df
# Out:
#    Year        Sales
# 0  2015  479856.2081
# 1  2016  459436.0054
# 2  2017  600192.5500
# 3  2018  722052.0192

# %%
plt.bar(year_df["Year"], year_df["Sales"])
plt.xlabel("Years")
plt.ylabel("Sales Volume")
plt.xticks(fontsize=8,rotation=90)
plt.yticks(fontsize=8)
plt.title('Sales Volume by Year', fontsize=13)
plt.show()

# %% [markdown]
# ### The Top 20 Customers by Sales

# %%
Costumer= df.groupby('Customer Name')['Sales'].sum().sort_values(ascending=False).reset_index()
Costumer
# Out:
#        Customer Name      Sales
# 0        Sean Miller  25043.050
# 1       Tamara Chand  19052.218
# 2       Raymond Buch  15117.339
# 3       Tom Ashbrook  14595.620
# 4      Adrian Barton  14473.571
# ..               ...        ...
# 788  Mitch Gastineau     16.739
# 789     Carl Jackson     16.520
# 790       Sung Chung     14.112
# 791     Lela Donovan      5.304
# 792    Thais Sissman      4.833
#
# [793 rows x 2 columns]

# %%
Costumer=Costumer.head(20)
Costumer
# Out:
#          Customer Name      Sales
# 0          Sean Miller  25043.050
# 1         Tamara Chand  19052.218
# 2         Raymond Buch  15117.339
# 3         Tom Ashbrook  14595.620
# 4        Adrian Barton  14473.571
# 5         Ken Lonsdale  14175.229
# 6         Sanjit Chand  14142.334
# 7         Hunter Lopez  12873.298
# 8         Sanjit Engle  12209.438
# 9   Christopher Conant  12129.072
# 10        Todd Sumrall  11891.751
# 11           Greg Tran  11820.120
# 12        Becky Martin  11789.630
# 13         Seth Vernon  11470.950
# 14     Caroline Jumper  11164.974
# 15         Clay Ludtke  10880.546
# 16       Maria Etezadi  10663.728
# 17      Karen Ferguson  10604.266
# 18        Bill Shonely  10501.653
# 19        Edward Hooks   9940.380

# %%
plt.bar(Costumer["Customer Name"], Costumer["Sales"])
plt.xlabel("Customer")
plt.ylabel("Sales Volume")
plt.xticks(fontsize=8,rotation=90)
plt.yticks(fontsize=8)
plt.title('The Top 20 Ranked Customers by Sales', fontsize=13)
plt.show()

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1     CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2     CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4     US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9795  CA-2017-125920 2017-05-21 2017-05-28  Standard Class    SH-19975
# 9796  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
# 9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
Category= df.groupby('Category')['Sales'].sum().reset_index()
Category
# Out:
#           Category        Sales
# 0        Furniture  728658.5757
# 1  Office Supplies  705422.3340
# 2       Technology  827455.8730

# %%
plt.bar(Category["Category"], Category["Sales"])
plt.xlabel("Category")
plt.ylabel("Sales Volume")
plt.title('Total Sales by Category', fontsize=13)
plt.show()

# %%
labels = Category['Category'].tolist()  
sizes = Category['Sales'].tolist()     
colors = ['#ff9999', '#66b3ff', '#99ff99']
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops={'edgecolor': 'black'})
plt.axis('equal')
plt.title('Sales Distribution by Category')
plt.show()

# %%
plt.pie(Category["Sales"],
labels=Category["Category"],
autopct="%0.2f%%",
explode=[0,0.1,0])
plt.title('Sales Distribution by Category')
# Out:
# Text(0.5, 1.0, 'Sales Distribution by Category')
